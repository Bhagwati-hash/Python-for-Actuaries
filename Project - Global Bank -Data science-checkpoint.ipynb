# %%
# library we are going to use 
# pip install pandas
# pip install numpy ( mathmatival compiutation)
#  pip install matplotlib (graphs and charts)
#  pip install seaborn ( graph and charts)
# pip install chart-studio ( interective charts)
# pip install cufflinks ( charts)
# pip install pandas-datareader ( helps in reading the data from various API's)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
from pandas_datareader import data,wb

# %% [markdown]
# Bank of America
#
# Citi group
#
# Goldman sachs
#
# Jpmorgan Chase
#
# Morgan Stanley

# %%
# creting a time line that i want to analyze the data of above global banks from year 2006 to year 2016
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2022,6,1)

# %%
#Bank of america ( triger point is BAC and source is yahoo)
BAC=data.DataReader('BAC','yahoo',start,end)

# %%
BAC
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03   5.890000   5.740000   5.750000   5.800000  246293200.0   4.965775
# 2012-01-04   5.880000   5.620000   5.710000   5.810000  243711200.0   4.974338
# 2012-01-05   6.350000   5.710000   5.750000   6.310000  547780000.0   5.402422
# 2012-01-06   6.300000   6.060000   6.210000   6.180000  299630600.0   5.291120
# 2012-01-09   6.370000   6.190000   6.260000   6.270000  240614400.0   5.368176
# ...               ...        ...        ...        ...          ...        ...
# 2022-05-25  36.270000  35.290001  35.500000  35.840000   49343400.0  35.634754
# 2022-05-26  36.840000  36.340000  36.500000  36.669998   60201200.0  36.459999
# 2022-05-27  37.049999  36.580002  36.889999  37.020000   43365600.0  36.807995
# 2022-05-31  37.529999  36.610001  36.820000  37.200001   71609200.0  36.986965
# 2022-06-01  37.470001  36.169998  37.459999  36.669998   35237900.0  36.459999
#
# [2621 rows x 6 columns]

# %%
BAC.head(5)
# Out:
#             High   Low  Open  Close       Volume  Adj Close
# Date
# 2012-01-03  5.89  5.74  5.75   5.80  246293200.0   4.965775
# 2012-01-04  5.88  5.62  5.71   5.81  243711200.0   4.974338
# 2012-01-05  6.35  5.71  5.75   6.31  547780000.0   5.402422
# 2012-01-06  6.30  6.06  6.21   6.18  299630600.0   5.291120
# 2012-01-09  6.37  6.19  6.26   6.27  240614400.0   5.368176

# %%
BAC.tail()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2022-05-25  36.270000  35.290001  35.500000  35.840000  49343400.0  35.634754
# 2022-05-26  36.840000  36.340000  36.500000  36.669998  60201200.0  36.459999
# 2022-05-27  37.049999  36.580002  36.889999  37.020000  43365600.0  36.807995
# 2022-05-31  37.529999  36.610001  36.820000  37.200001  71609200.0  36.986965
# 2022-06-01  37.470001  36.169998  37.459999  36.669998  35237900.0  36.459999

# %%
# citi group
C=data.DataReader('C','yahoo',start,end)

# %%
C.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  28.510000  27.129999  27.129999  28.330000  58169500.0  23.968817
# 2012-01-04  28.379999  27.620001  28.040001  28.170000  41455000.0  23.833450
# 2012-01-05  29.180000  27.469999  27.660000  28.510000  66793300.0  24.121107
# 2012-01-06  29.059999  28.010000  28.660000  28.549999  48226900.0  24.154949
# 2012-01-09  29.379999  28.650000  28.719999  29.080000  35017900.0  24.603363

# %%
#Goldmansachs , jpmorgan chase ,Morgan stanley
GS=data.DataReader('GS','yahoo',start,end)
JPM=data.DataReader('JPM','yahoo',start,end)
MS=data.DataReader('MS','yahoo',start,end)

# %%
MS.head()
# Out:
#                  High    Low   Open      Close      Volume  Adj Close
# Date
# 2012-01-03  16.290001  15.71  15.76  16.080000  25777400.0  13.039812
# 2012-01-04  16.080000  15.50  15.75  15.940000  20699600.0  12.926282
# 2012-01-05  16.400000  15.43  15.59  16.280001  30615100.0  13.202003
# 2012-01-06  16.250000  15.80  16.08  15.900000  21677700.0  12.893845
# 2012-01-09  16.450001  15.93  16.00  16.200001  19102900.0  13.137126

# %%
tickers=['BAC','C','GS','JPM','MS']

# %%
# CONCATENATE
bank_stocks=pd.concat([BAC,C,GS,JPM,MS],axis=1,keys=tickers)
#axis=1 will concatenate according to columns

# %%
bank_stocks.head()
# Out:
#              BAC                                                   C  \
#             High   Low  Open Close       Volume Adj Close       High
# Date
# 2012-01-03  5.89  5.74  5.75  5.80  246293200.0  4.965775  28.510000
# 2012-01-04  5.88  5.62  5.71  5.81  243711200.0  4.974338  28.379999
# 2012-01-05  6.35  5.71  5.75  6.31  547780000.0  5.402422  29.180000
# 2012-01-06  6.30  6.06  6.21  6.18  299630600.0  5.291120  29.059999
# 2012-01-09  6.37  6.19  6.26  6.27  240614400.0  5.368176  29.379999
#
#                                              ...        JPM             \
#                   Low       Open      Close  ...       Open      Close
# Date                                         ...
# 2012-01-03  27.129999  27.129999  28.330000  ...  34.060001  34.980000
# 2012-01-04  27.620001  28.040001  28.170000  ...  34.439999  34.950001
# 2012-01-05  27.469999  27.660000  28.510000  ...  34.709999  35.680000
# 2012-01-06  28.010000  28.660000  28.549999  ...  35.689999  35.360001
# 2012-01-09  28.650000  28.719999  29.080000  ...  35.439999  35.299999
#
#                                           MS                           \
#                 Volume  Adj Close       High    Low   Open      Close
# Date
# 2012-01-03  44102800.0  26.197294  16.290001  15.71  15.76  16.080000
# 2012-01-04  36571200.0  26.363234  16.080000  15.50  15.75  15.940000
# 2012-01-05  38381400.0  26.913885  16.400000  15.43  15.59  16.280001
# 2012-01-06  33160600.0  26.672503  16.250000  15.80  16.08  15.900000
# 2012-01-09  23001800.0  26.627243  16.450001  15.93  16.00  16.200001
#
#
#                 Volume  Adj Close
# Date
# 2012-01-03  25777400.0  13.039812
# 2012-01-04  20699600.0  12.926282
# 2012-01-05  30615100.0  13.202003
# 2012-01-06  21677700.0  12.893845
# 2012-01-09  19102900.0  13.137126
#
# [5 rows x 30 columns]

# %%
bank_stocks.columns.names=['Bank,Ticker','Stock info']

# %%
bank_stocks.head()
# Out:
# Bank,Ticker   BAC                                                   C  \
# Stock info   High   Low  Open Close       Volume Adj Close       High
# Date
# 2012-01-03   5.89  5.74  5.75  5.80  246293200.0  4.965775  28.510000
# 2012-01-04   5.88  5.62  5.71  5.81  243711200.0  4.974338  28.379999
# 2012-01-05   6.35  5.71  5.75  6.31  547780000.0  5.402422  29.180000
# 2012-01-06   6.30  6.06  6.21  6.18  299630600.0  5.291120  29.059999
# 2012-01-09   6.37  6.19  6.26  6.27  240614400.0  5.368176  29.379999
#
# Bank,Ticker                                   ...        JPM             \
# Stock info         Low       Open      Close  ...       Open      Close
# Date                                          ...
# 2012-01-03   27.129999  27.129999  28.330000  ...  34.060001  34.980000
# 2012-01-04   27.620001  28.040001  28.170000  ...  34.439999  34.950001
# 2012-01-05   27.469999  27.660000  28.510000  ...  34.709999  35.680000
# 2012-01-06   28.010000  28.660000  28.549999  ...  35.689999  35.360001
# 2012-01-09   28.650000  28.719999  29.080000  ...  35.439999  35.299999
#
# Bank,Ticker                                MS                           \
# Stock info       Volume  Adj Close       High    Low   Open      Close
# Date
# 2012-01-03   44102800.0  26.197294  16.290001  15.71  15.76  16.080000
# 2012-01-04   36571200.0  26.363234  16.080000  15.50  15.75  15.940000
# 2012-01-05   38381400.0  26.913885  16.400000  15.43  15.59  16.280001
# 2012-01-06   33160600.0  26.672503  16.250000  15.80  16.08  15.900000
# 2012-01-09   23001800.0  26.627243  16.450001  15.93  16.00  16.200001
#
# Bank,Ticker
# Stock info       Volume  Adj Close
# Date
# 2012-01-03   25777400.0  13.039812
# 2012-01-04   20699600.0  12.926282
# 2012-01-05   30615100.0  13.202003
# 2012-01-06   21677700.0  12.893845
# 2012-01-09   19102900.0  13.137126
#
# [5 rows x 30 columns]

# %% [markdown]
# # problem statements

# %% [markdown]
# **question 1 : what is the maximum close price for each back's stock throughout the time period**

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 49.380001068115234

# %%
# ONE RULE in Programming is DRY ' do not rpeat yourself'
# so we will create a d¨for loop

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS']

# %%
# for loop for getting max clsoe price for all of the 5 banks at once
for i in tickers:
    print('The answer of',i,'is',bank_stocks[i]['Close'].max())
# Out:
# The answer of BAC is 49.380001068115234
# The answer of C is 81.91000366210938
# The answer of GS is 423.8500061035156
# The answer of JPM is 171.77999877929688
# The answer of MS is 108.7300033569336

# %%
# cross section
# cross section is used for multilevel indexing
bank_stocks.head()
# Out:
# Bank,Ticker   BAC                                                   C  \
# Stock info   High   Low  Open Close       Volume Adj Close       High
# Date
# 2012-01-03   5.89  5.74  5.75  5.80  246293200.0  4.965775  28.510000
# 2012-01-04   5.88  5.62  5.71  5.81  243711200.0  4.974338  28.379999
# 2012-01-05   6.35  5.71  5.75  6.31  547780000.0  5.402422  29.180000
# 2012-01-06   6.30  6.06  6.21  6.18  299630600.0  5.291120  29.059999
# 2012-01-09   6.37  6.19  6.26  6.27  240614400.0  5.368176  29.379999
#
# Bank,Ticker                                   ...        JPM             \
# Stock info         Low       Open      Close  ...       Open      Close
# Date                                          ...
# 2012-01-03   27.129999  27.129999  28.330000  ...  34.060001  34.980000
# 2012-01-04   27.620001  28.040001  28.170000  ...  34.439999  34.950001
# 2012-01-05   27.469999  27.660000  28.510000  ...  34.709999  35.680000
# 2012-01-06   28.010000  28.660000  28.549999  ...  35.689999  35.360001
# 2012-01-09   28.650000  28.719999  29.080000  ...  35.439999  35.299999
#
# Bank,Ticker                                MS                           \
# Stock info       Volume  Adj Close       High    Low   Open      Close
# Date
# 2012-01-03   44102800.0  26.197294  16.290001  15.71  15.76  16.080000
# 2012-01-04   36571200.0  26.363234  16.080000  15.50  15.75  15.940000
# 2012-01-05   38381400.0  26.913885  16.400000  15.43  15.59  16.280001
# 2012-01-06   33160600.0  26.672503  16.250000  15.80  16.08  15.900000
# 2012-01-09   23001800.0  26.627243  16.450001  15.93  16.00  16.200001
#
# Bank,Ticker
# Stock info       Volume  Adj Close
# Date
# 2012-01-03   25777400.0  13.039812
# 2012-01-04   20699600.0  12.926282
# 2012-01-05   30615100.0  13.202003
# 2012-01-06   21677700.0  12.893845
# 2012-01-09   19102900.0  13.137126
#
# [5 rows x 30 columns]

# %%
# we can extract max close price for all the banks using crossection
bank_stocks.xs(key='Close',axis=1,level='Stock info').max()
# Out:
# Bank,Ticker
# BAC     49.380001
# C       81.910004
# GS     423.850006
# JPM    171.779999
# MS     108.730003
# dtype: float64

# %% [markdown]
# **returns = (value at time t - value at time (t-1))/ value at time (t-1)**

# %%
returns=pd.DataFrame()

# %%
# for loop for getting return percentage for all of the banks
for i in tickers:
    returns[i  +  'return']=bank_stocks[i]['Close'].pct_change()

# %%
returns
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2012-01-03        NaN       NaN       NaN        NaN       NaN
# 2012-01-04   0.001724 -0.005648 -0.006502  -0.000858 -0.008706
# 2012-01-05   0.086059  0.012070 -0.001689   0.020887  0.021330
# 2012-01-06  -0.020602  0.001403 -0.012265  -0.008969 -0.023342
# 2012-01-09   0.014563  0.018564  0.013595  -0.001697  0.018868
# ...               ...       ...       ...        ...       ...
# 2022-05-25   0.005330  0.000380  0.003026   0.006964  0.003294
# 2022-05-26   0.023158  0.026376  0.027723   0.017290  0.033686
# 2022-05-27   0.009545 -0.008689  0.015295   0.014138  0.017059
# 2022-05-31   0.004862 -0.003916 -0.005265   0.007313 -0.003586
# 2022-06-01  -0.014247 -0.019098 -0.015298  -0.017545 -0.013234
#
# [2621 rows x 5 columns]

# %% [markdown]
# **question: 2 which dates each banks has the best and worst single day returns**

# %%
# the worst date for each of the bank
returns.idxmin()
# Out:
# BACreturn   2020-03-16
# Creturn     2020-03-16
# GSreturn    2020-03-16
# JPMreturn   2020-03-16
# MSreturn    2020-03-16
# dtype: datetime64[ns]

# %%
# the best date for each of the bank
returns.idxmax()
# Out:
# BACreturn   2020-03-13
# Creturn     2020-03-13
# GSreturn    2020-03-13
# JPMreturn   2020-03-13
# MSreturn    2020-03-13
# dtype: datetime64[ns]

# %% [markdown]
# **question:3**
#
#    **a .Which stock would you classify as the riskiest during the entire time period**
#
#    **b.Which whould you classify as the riskiest during 2015**

# %%
# we need to see the standard deviation  of returns
returns.std()
# Out:
# BACreturn    0.019925
# Creturn      0.020433
# GSreturn     0.017603
# JPMreturn    0.016950
# MSreturn     0.020186
# dtype: float64

# %%
# above we can see that the citi bnak group is the riskiest since it has max standard deviation

# %%
# if i want to extract the index for most riskiest bank
returns.std().idxmax()
# Out:
# 'Creturn'

# %%
# extracting 2015 data from dataframe returns
returns.loc['2015-01-01':'2015-12-31']
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2015-01-02   0.000559  0.002772  0.002992  -0.001438 -0.002320
# 2015-01-05  -0.029050 -0.031515 -0.031223  -0.031045 -0.031258
# 2015-01-06  -0.029919 -0.035205 -0.020229  -0.025929 -0.028800
# 2015-01-07   0.004745  0.009270  0.014903   0.001526  0.014278
# 2015-01-08   0.020661  0.015048  0.015965   0.022346  0.014889
# ...               ...       ...       ...        ...       ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031
#
# [252 rows x 5 columns]

# %%
# riskiest in year 2015
returns.loc['2015-01-01':'2015-12-31'].std().idxmax()
# Out:
# 'MSreturn'

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **creating a distribution plot for Morgan Stanley**

# %%
y=returns.loc['2015-01-01':'2015-12-31']

# %%
y.head()
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2015-01-02   0.000559  0.002772  0.002992  -0.001438 -0.002320
# 2015-01-05  -0.029050 -0.031515 -0.031223  -0.031045 -0.031258
# 2015-01-06  -0.029919 -0.035205 -0.020229  -0.025929 -0.028800
# 2015-01-07   0.004745  0.009270  0.014903   0.001526  0.014278
# 2015-01-08   0.020661  0.015048  0.015965   0.022346  0.014889

# %%
sns.displot(y['MSreturn'],kde=True,color='green',bins=30)

# %%
# above we can see that its a normal distribution

# %% [markdown]
# **creating a distribution plot for year 2008 returns of citibank group**

# %%
z=returns.loc['2021-06-01':'2021-12-31']

# %%
sns.displot(z['Creturn'],kde=True,color='purple',bins=30)

# %%
# above plot we can see that the variabilty of returns for citigroup banks varies from -20% to 60 % wheresas for Morgan stanley 
# it varies from -6% to 6% so it is agin showing our analysis which we have done earlier that citibank group is the riskiest

# %% [markdown]
# # **interactive plotting**

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for i in tickers:
    bank_stocks[i]['Close'].plot(label=i,figsize=(12,6))
    plt.legend()

# %%
# instead of using loop we can also use cross section
bank_stocks.xs(key='Close',axis=1,level='Stock info').plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # interactive ploting

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock info').iplot()
# Out:
# <div>                            <div id="2d2afa87-530c-4a79-aea8-697f84ee9c39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("2d2afa87-530c-4a79-aea8-697f84ee9c39")) {                    Plotly.newPlot(                        "2d2afa87-530c-4a79-aea8-697f84ee9c39",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"BAC","text":"","type":"scatter","x":["2012-01-03","2012-01-04","2012-01-05","2012-01-06","2012-01-09","2012-01-10","2012-01-11","2012-01-12","2012-01-13","2012-01-17","2012-01-18","2012-01-19","2012-01-20","2012-01-23","2012-01-24","2012-01-25","2012-01-26","2012-01-27","2012-01-30","2012-01-31","2012-02-01","2012-02-02","2012-02-03","2012-02-06","2012-02-07","2012-02-08","2012-02-09","2012-02-10","2012-02-13","2012-02-14","2012-02-15","2012-02-16","2012-02-17","2012-02-21","2012-02-22","2012-02-23","2012-02-24","2012-02-27","2012-02-28","2012-02-29","2012-03-01","2012-03-02","2012-03-05","2012-03-06","2012-03-07","2012-03-08","2012-03-09","2012-03-12","2012-03-13","2012-03-14","2012-03-15","2012-03-16","2012-03-19","2012-03-20","2012-03-21","2012-03-22","2012-03-23","2012-03-26","2012-03-27","2012-03-28","2012-03-29","2012-03-30","2012-04-02","2012-04-03","2012-04-04","2012-04-05","2012-04-09","2012-04-10","2012-04-11","2012-04-12","2012-04-13","2012-04-16","2012-04-17","2012-04-18","2012-04-19","2012-04-20","2012-04-23","2012-04-24","2012-04-25","2012-04-26","2012-04-27","2012-04-30","2012-05-01","2012-05-02","2012-05-03","2012-05-04","2012-05-07","2012-05-08","2012-05-09","2012-05-10","2012-05-11","2012-05-14","2012-05-15","2012-05-16","2012-05-17","2012-05-18","2012-05-21","2012-05-22","2012-05-23","2012-05-24","2012-05-25","2012-05-29","2012-05-30","2012-05-31","2012-06-01","2012-06-04","2012-06-05","2012-06-06","2012-06-07","2012-06-08","2012-06-11","2012-06-12","2012-06-13","2012-06-14","2012-06-15","2012-06-18","2012-06-19","2012-06-20","2012-06-21","2012-06-22","2012-06-25","2012-06-26","2012-06-27","2012-06-28","2012-06-29","2012-07-02","2012-07-03","2012-07-05","2012-07-06","2012-07-09","2012-07-10","2012-07-11","2012-07-12","2012-07-13","2012-07-16","2012-07-17","2012-07-18","2012-07-19","2012-07-20","2012-07-23","2012-07-24","2012-07-25","2012-07-26","2012-07-27","2012-07-30","2012-07-31","2012-08-01","2012-08-02","2012-08-03","2012-08-06","2012-08-07","2012-08-08","2012-08-09","2012-08-10","2012-08-13","2012-08-14","2012-08-15","2012-08-16","2012-08-17","2012-08-20","2012-08-21","2012-08-22","2012-08-23","2012-08-24","2012-08-27","2012-08-28","2012-08-29","2012-08-30","2012-08-31","2012-09-04","2012-09-05","2012-09-06","2012-09-07","2012-09-10","2012-09-11","2012-09-12","2012-09-13","2012-09-14","2012-09-17","2012-09-18","2012-09-19","2012-09-20","2012-09-21","2012-09-24","2012-09-25","2012-09-26","2012-09-27","2012-09-28","2012-10-01","2012-10-02","2012-10-03","2012-10-04","2012-10-05","2012-10-08","2012-10-09","2012-10-10","2012-10-11","2012-10-12","2012-10-15","2012-10-16","2012-10-17","2012-10-18","2012-10-19","2012-10-22","2012-10-23","2012-10-24","2012-10-25","2012-10-26","2012-10-31","2012-11-01","2012-11-02","2012-11-05","2012-11-06","2012-11-07","2012-11-08","2012-11-09","2012-11-12","2012-11-13","2012-11-14","2012-11-15","2012-11-16","2012-11-19","2012-11-20","2012-11-21","2012-11-23","2012-11-26","2012-11-27","2012-11-28","2012-11-29","2012-11-30","2012-12-03","2012-12-04","2012-12-05","2012-12-06","2012-12-07","2012-12-10","2012-12-11","2012-12-12","2012-12-13","2012-12-14","2012-12-17","2012-12-18","2012-12-19","2012-12-20","2012-12-21","2012-12-24","2012-12-26","2012-12-27","2012-12-28","2012-12-31","2013-01-02","2013-01-03","2013-01-04","2013-01-07","2013-01-08","2013-01-09","2013-01-10","2013-01-11","2013-01-14","2013-01-15","2013-01-16","2013-01-17","2013-01-18","2013-01-22","2013-01-23","2013-01-24","2013-01-25","2013-01-28","2013-01-29","2013-01-30","2013-01-31","2013-02-01","2013-02-04","2013-02-0 ...

# %% [markdown]
# **moving averages**

# %%
plt.figure(figsize=(12,4))
#it will create a blank figure or chart
BAC['Close'].loc['2022-01-01':'2022-06-20'].rolling(window=30).mean().plot(label= '30 Day moving avearge')
BAC['Close'].loc['2022-01-01':'2022-06-20'].plot(label='BAC Close price')
plt.legend()

# %% [markdown]
# **Heatmap**

# %%
#correlation
bank_stocks.xs(key='Close',axis=1,level='Stock info').corr()
# Out:
# Bank,Ticker       BAC         C        GS       JPM        MS
# Bank,Ticker
# BAC          1.000000  0.805599  0.927278  0.984680  0.943459
# C            0.805599  1.000000  0.725183  0.800057  0.668280
# GS           0.927278  0.725183  1.000000  0.906779  0.980666
# JPM          0.984680  0.800057  0.906779  1.000000  0.925982
# MS           0.943459  0.668280  0.980666  0.925982  1.000000

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank,Ticker', ylabel='Bank,Ticker'>

# %%
# interactive heatmap
close_c=bank_stocks.xs(key='Close',axis=1,level='Stock info').corr()

# %%
close_c.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="8eddb84a-9759-4a72-9094-80f52fe6e098" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8eddb84a-9759-4a72-9094-80f52fe6e098")) {                    Plotly.newPlot(                        "8eddb84a-9759-4a72-9094-80f52fe6e098",                        [{"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,144)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(224,243,248)"],[0.7,"rgb(171,217,233)"],[0.8,"rgb(116,173,209)"],[0.9,"rgb(69,117,180)"],[1.0,"rgb(49,54,149)"]],"type":"heatmap","x":["BAC","C","GS","JPM","MS"],"y":["BAC","C","GS","JPM","MS"],"z":[[1.0,0.8055986202205846,0.9272778482775392,0.984679578915952,0.9434591275604804],[0.8055986202205846,1.0,0.725183167582411,0.8000569870240553,0.6682798533190526],[0.9272778482775392,0.725183167582411,1.0,0.9067792926131333,0.9806656240331092],[0.984679578915952,0.8000569870240553,0.9067792926131333,1.0,0.9259817307982002],[0.9434591275604804,0.6682798533190526,0.9806656240331092,0.9259817307982002,1.0]],"zmax":1.0,"zmin":0.6682798533190526}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dc ...

# %%
# candelstick charts 
BAC.head()
# Out:
#             High   Low  Open  Close       Volume  Adj Close
# Date
# 2012-01-03  5.89  5.74  5.75   5.80  246293200.0   4.965775
# 2012-01-04  5.88  5.62  5.71   5.81  243711200.0   4.974338
# 2012-01-05  6.35  5.71  5.75   6.31  547780000.0   5.402422
# 2012-01-06  6.30  6.06  6.21   6.18  299630600.0   5.291120
# 2012-01-09  6.37  6.19  6.26   6.27  240614400.0   5.368176

# %%
 bac_2022=BAC[['Open','High','Low','Close']].loc['2021-01-01':'2022-06-20']

# %%
bac_2022.iplot(kind='candle')
# Out:
# <div>                            <div id="4fe13470-c32f-4ec4-b19b-3e8da03e3880" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("4fe13470-c32f-4ec4-b19b-3e8da03e3880")) {                    Plotly.newPlot(                        "4fe13470-c32f-4ec4-b19b-3e8da03e3880",                        [{"close":[30.030000686645508,30.260000228881836,32.150001525878906,32.86000061035156,32.529998779296875,33.06999969482422,33.65999984741211,33.459999084472656,33.9900016784668,33.0099983215332,32.77000045776367,32.34000015258789,31.770000457763672,31.549999237060547,31.15999984741211,30.940000534057617,29.829999923706055,30.31999969482422,29.649999618530273,29.959999084472656,31.030000686645508,31.579999923706055,32.5,32.369998931884766,33.09000015258789,32.95000076293945,32.97999954223633,32.880001068115234,33.369998931884766,34.27000045776367,34.40999984741211,34.189998626708984,34.540000915527344,35.150001525878906,35.52000045776367,36.380001068115234,35.93000030517578,34.709999084472656,35.790000915527344,35.529998779296875,36.41999816894531,36.5,36.93000030517578,37.130001068115234,36.31999969482422,37.369998931884766,37.2400016784668,37.939998626708984,37.75,37.63999938964844,37.95000076293945,38.939998626708984,38.529998779296875,37.65999984741211,36.900001525878906,36.900001525878906,37.65999984741211,38.68000030517578,38.310001373291016,38.9900016784668,38.689998626708984,39.4900016784668,39.79999923706055,39.689998626708984,40.04999923706055,39.70000076293945,39.9900016784668,40.060001373291016,39.31999969482422,39.880001068115234,38.7400016784668,39.150001525878906,39.16999816894531,38.08000183105469,38.720001220703125,38.36000061035156,39.18000030517578,39.40999984741211,39.880001068115234,40.029998779296875,41.11000061035156,40.529998779296875,40.560001373291016,41.0,41.38999938964844,42.0099983215332,42.18000030517578,42.04999923706055,41.56999969482422,41.18000030517578,41.84000015258789,42.36000061035156,42.7400016784668,42.15999984741211,41.970001220703125,41.869998931884766,42.400001525878906,42.630001068115234,42.0099983215332,42.040000915527344,42.54999923706055,42.38999938964844,42.91999816894531,42.939998626708984,43.25,43.27000045776367,43.119998931884766,42.880001068115234,42.31999969482422,41.689998626708984,41.86000061035156,41.36000061035156,41.38999938964844,41.619998931884766,39.79999923706055,38.779998779296875,39.75,39.970001220703125,40.20000076293945,40.83000183105469,41.619998931884766,41.560001373291016,40.88999938964844,41.22999954223633,41.540000915527344,41.150001525878906,40.06999969482422,39.75,38.779998779296875,40.040000915527344,40.630001068115234,39.86000061035156,38.86000061035156,38.83000183105469,37.91999816894531,36.93000030517578,37.689998626708984,38.459999084472656,37.959999084472656,37.70000076293945,38.130001068115234,37.97999954223633,38.130001068115234,38.68000030517578,38.36000061035156,37.959999084472656,38.54999923706055,38.27000045776367,39.02000045776367,40.150001525878906,40.66999816894531,41.43000030517578,41.95000076293945,42.150001525878906,41.630001068115234,41.290000915527344,41.09000015258789,40.790000915527344,40.189998626708984,40.369998931884766,40.90999984741211,41.47999954223633,42.150001525878906,42.040000915527344,42.4900016784668,41.65999984741211,41.75,41.189998626708984,41.02000045776367,41.04999923706055,41.31999969482422,40.779998779296875,40.93000030517578,40.27000045776367,40.939998626708984,39.84000015258789,40.13999938964844,40.45000076293945,40.5,39.11000061035156,39.130001068115234,40.13999938964844,41.689998626708984,42.13999938964844,43.2599983215332,43.15999984741211,43.06999969482422,42.45000076293945,43.08000183105469,43.34000015258789,44.220001220703125,44.2400016784668,44.119998931884766,44.34000015258789,43.779998779296875,43.540000915527344,43.13999938964844,45.06999969482422,46.369998931884766,46.279998779296875,46.47999954223633,47.09000015258789,46.83000183105469,47.56999969482422,47.5099983215332,47.959999084472656,47.040000915527344,47.779998 ...
